# %%
#BM Talos Single headed network year 1 hyperparameter search w/results
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_A_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)
# Out:
# 2023-09-08 20:10:28.497006: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-08 20:10:28.526022: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-08 20:10:29.026869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_B_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)

Y=dat.iloc[:, 0:24]
X=dat.iloc[:,24:]
X_train=X.iloc[:3624,:]
Y_train=Y.iloc[:3624,:]
X_test=X.iloc[3624:3625,:]
Y_test=Y.iloc[3624:3625,:]

# %%
#BM Talos Single headed network year 1 hyperparameter search w/results
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_B_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)


Y=dat.iloc[:, 0:24]
X=dat.iloc[:,24:]
X_train=X.iloc[:3624,:]
Y_train=Y.iloc[:3624,:]
X_test=X.iloc[3624:4368,:]
Y_test=Y.iloc[3624:4368,:]

def qloss(qs, y_true, y_pred):
    # Pinball loss for multiple quantiles
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

loss_10th_p = lambda y_true, y_pred: qloss(0.1, y_true, y_pred)
loss_30th_p = lambda y_true, y_pred: qloss(0.3, y_true, y_pred)
loss_50th_p = lambda y_true, y_pred: qloss(0.5, y_true, y_pred)
loss_70th_p = lambda y_true, y_pred: qloss(0.7, y_true, y_pred)
loss_90th_p = lambda y_true, y_pred: qloss(0.9, y_true, y_pred)


P_10_A = X_train.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_train.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_train.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_train.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_train.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]



rnn_train_1=X_train.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_train_2=X_train.loc[:,"WF" : "WF-143"]   
rnn_train_3=X_train.loc[:,"DF" : "DF-143"] 
rnn_train_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_train_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_train_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_train_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_train_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)


P_10_A = X_test.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_test.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_test.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_test.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_test.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]


rnn_test_1=X_test.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_test_2=X_test.loc[:,"WF":"WF-143"] 
rnn_test_3=X_test.loc[:,"DF" : "DF-143"]
rnn_test_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_test_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_test_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_test_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_test_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)

rnn_Y=Y_train.loc[:,"EURPrices":"EURPrices+23"]
rnn_test_Y=Y_test.loc[:,"EURPrices":"EURPrices+23"]

X_scaler1 = preprocessing.MinMaxScaler()
X_scaler2 = preprocessing.MinMaxScaler()
X_scaler3 = preprocessing.MinMaxScaler()
X_scaler4 = preprocessing.MinMaxScaler()
X_scaler5 = preprocessing.MinMaxScaler()
X_scaler6 = preprocessing.MinMaxScaler()
X_scaler7 = preprocessing.MinMaxScaler()
X_scaler8 = preprocessing.MinMaxScaler()

Y_scaler = preprocessing.MinMaxScaler()

rnn_scaled_train_1 = X_scaler1.fit_transform(rnn_train_1)
rnn_scaled_train_2 = X_scaler2.fit_transform(rnn_train_2)
rnn_scaled_train_3 = X_scaler3.fit_transform(rnn_train_3)
rnn_scaled_train_4 = X_scaler4.fit_transform(rnn_train_4)
rnn_scaled_train_5 = X_scaler5.fit_transform(rnn_train_5)
rnn_scaled_train_6 = X_scaler6.fit_transform(rnn_train_6)
rnn_scaled_train_7 = X_scaler7.fit_transform(rnn_train_7)
rnn_scaled_train_8 = X_scaler8.fit_transform(rnn_train_8)


Y_train_Scaled   = Y_scaler.fit_transform(rnn_Y)
Y_test_Scaled = Y_scaler.transform(rnn_test_Y)
 
X_train_Scaled = np.hstack(
    (rnn_scaled_train_1, rnn_scaled_train_2, rnn_scaled_train_3)
).reshape(rnn_train_1.shape[0], 3, 144).transpose(0, 2, 1)

X_train_Scaled_QRA = np.hstack(
    (rnn_scaled_train_4, rnn_scaled_train_5, rnn_scaled_train_6,
     rnn_scaled_train_7, rnn_scaled_train_8)
).reshape(rnn_train_4.shape[0], 5, 72).transpose(0, 2, 1)


X_test_Scaled = np.hstack(
    (X_scaler1.transform(rnn_test_1), X_scaler2.transform(rnn_test_2), X_scaler3.transform(rnn_test_3)
    )
).reshape(rnn_test_1.shape[0], 3, 144).transpose(0, 2, 1)

X_test_Scaled_QRA = np.hstack(
    (X_scaler4.transform(rnn_test_4), X_scaler5.transform(rnn_test_5), X_scaler6.transform(rnn_test_6), 
     X_scaler7.transform(rnn_test_7),X_scaler8.transform(rnn_test_8)
     )
).reshape(rnn_test_4.shape[0], 5, 72).transpose(0, 2, 1)

i_shape_QRA = (X_train_Scaled_QRA.shape[1], X_train_Scaled_QRA.shape[2])
i_shape_dnn=(X_train_Scaled.shape[1], X_train_Scaled.shape[2])

pp ={
    'dropout_rate_A': list(np.linspace(0.0,0.4, 10)),
    'dropout_rate_B': list(np.linspace(0.0,0.4, 10)),
   
    'activation_A':['relu', 'sigmoid',  'tanh'],
    'activation_B':['relu', 'sigmoid',  'tanh'],
    'activation_o_10':['relu', 'sigmoid',  'tanh'],
    'activation_o_30':['relu', 'sigmoid',  'tanh'],
    'activation_o_50':['relu', 'sigmoid',  'tanh'],
    'activation_o_70':['relu', 'sigmoid',  'tanh'],
    'activation_o_90':['relu', 'sigmoid',  'tanh'],
   
    'ffnn_neurons_A': [24, 48, 96, 192, 288],
    'ffnn_neurons_B': [24, 48, 96, 192, 288],
    'n_neuro_o_10': [24, 48, 96, 192, 288],
    'n_neuro_o_30': [24, 48, 96, 192, 288],
    'n_neuro_o_50': [24, 48, 96, 192, 288],
    'n_neuro_o_70': [24, 48, 96, 192, 288],
    'n_neuro_o_90': [24, 48, 96, 192, 288],
    
    'n_layer_A':[1,2,3],    
    'n_layer_B':[1,2,3],    
    'n_layer_o_10':[1,2,3],    
    'n_layer_o_30':[1,2,3],    
    'n_layer_o_50':[1,2,3],    
    'n_layer_o_70':[1,2,3],    
    'n_layer_o_90':[1,2,3],    

    
    'learning_rate': list(np.linspace(0.0001,0.02, 10)),        
    'batch_size': [4, 8, 16, 32],
    'epochs': [300]    
}


def create_model(x_train, y_train, x_val, y_val, params): 
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(params['n_layer_A']):
        input_00_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_00_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_00_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_00_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(params['n_layer_A']):
        input_10_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_10_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_10_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_10_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(params['n_layer_A']):
        input_20_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_20_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_20_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_20_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(params['n_layer_A']):
        input_30_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_30_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_30_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_30_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(params['n_layer_A']):
        input_40_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_40_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_40_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_40_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(params['n_layer_o_10']):
            merged_1 = Dense(params['n_neuro_o_10'], params['activation_o_10'])(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(params['n_layer_o_30']):
            merged_3 = Dense(params['n_neuro_o_30'], params['activation_o_30'])(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(params['n_layer_o_50']):
            merged_5 = Dense(params['n_neuro_o_50'], params['activation_o_50'])(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(params['n_layer_o_70']):
            merged_7 = Dense(params['n_neuro_o_70'], params['activation_o_70'])(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(params['n_layer_o_90']):
            merged_9 = Dense(params['n_neuro_o_90'], params['activation_o_90'])(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)


    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= params['learning_rate'])

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)


    out = model.fit(x=x_train, y=y_train, validation_data=[x_val, y_val],
                    batch_size=params['batch_size'], epochs=params['epochs'], verbose=2,
                    callbacks=[talos.utils.early_stopper(epochs=params['epochs'], mode='moderate',
                                                         min_delta=0.001, monitor='val_loss')])
    return out, model
        
h = talos.Scan(x=[X_train_Scaled_QRA, X_train_Scaled], y=[Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled],
               x_val=[X_test_Scaled_QRA, X_test_Scaled], y_val=[Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled],
               params=pp, model=create_model, experiment_name='MH_DNN_Q', round_limit=30, print_params=True, multi_input=True)

h.data.sort_values(by='val_loss', ascending=True)


def create_model():
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(3):
        input_00_A = Dense(24, 'sigmoid')(input_00_A) 
    input_00_A = Dropout(0.400000)(input_00_A)    
    for i in range(2):
        input_00_B = Dense(48, 'sigmoid')(input_00_B) 
    input_00_B = Dropout(0.044444)(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(3):
        input_10_A = Dense(24, 'sigmoid')(input_00_A) 
    input_10_A = Dropout(0.400000)(input_00_A)    
    for i in range(2):
        input_10_B = Dense(48, 'sigmoid')(input_00_B) 
    input_10_B = Dropout(0.044444)(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(3):
        input_20_A = Dense(24, 'sigmoid')(input_00_A) 
    input_20_A = Dropout(0.400000)(input_00_A)    
    for i in range(2):
        input_20_B = Dense(48, 'sigmoid')(input_00_B) 
    input_20_B = Dropout(0.044444)(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(3):
        input_30_A = Dense(24, 'sigmoid')(input_00_A) 
    input_30_A = Dropout(0.400000)(input_00_A)    
    for i in range(2):
        input_30_B = Dense(48, 'sigmoid')(input_00_B) 
    input_30_B = Dropout(0.044444)(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(3):
        input_40_A = Dense(24, 'sigmoid')(input_00_A) 
    input_40_A = Dropout(0.400000)(input_00_A)    
    for i in range(2):
        input_40_B = Dense(48, 'sigmoid')(input_00_B) 
    input_40_B = Dropout(0.044444)(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(2):
            merged_1 = Dense(480, 'tanh')(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(2):
            merged_3 = Dense(48, 'relu')(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(2):
            merged_5 = Dense(192, 'relu')(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(3):
            merged_7 = Dense(96, 'sigmoid')(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(2):
            merged_9 = Dense(192, 'tanh')(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)    
    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= 0.002311)

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)
    return model

mmo = KerasRegressor(build_fn=create_model, epochs=300, batch_size=32, verbose=2)
# Out:
#   0%|                                                                                                                                                                                | 0/30 [00:00<?, ?it/s]
# {'dropout_rate_A': 0.4, 'dropout_rate_B': 0.22222222222222224, 'activation_A': 'relu', 'activation_B': 'relu', 'activation_o_10': 'relu', 'activation_o_30': 'tanh', 'activation_o_50': 'tanh', 'activation_o_70': 'tanh', 'activation_o_90': 'sigmoid', 'ffnn_neurons_A': 24, 'ffnn_neurons_B': 48, 'n_neuro_o_10': 384, 'n_neuro_o_30': 480, 'n_neuro_o_50': 96, 'n_neuro_o_70': 384, 'n_neuro_o_90': 24, 'n_layer_A': 2, 'n_layer_B': 2, 'n_layer_o_10': 3, 'n_layer_o_30': 1, 'n_layer_o_50': 2, 'n_layer_o_70': 3, 'n_layer_o_90': 3, 'learning_rate': 0.01778888888888889, 'batch_size': 4, 'epochs': 300}
# ...

# %%
#BM Talos Single headed network year 1 hyperparameter search w/results
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_B_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)


Y=dat.iloc[:, 0:24]
X=dat.iloc[:,24:]
X_train=X.iloc[:5112,:]
Y_train=Y.iloc[:5112,:]
X_test=X.iloc[5112:5856,:]
Y_test=Y.iloc[5112:5856,:]

def qloss(qs, y_true, y_pred):
    # Pinball loss for multiple quantiles
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

loss_10th_p = lambda y_true, y_pred: qloss(0.1, y_true, y_pred)
loss_30th_p = lambda y_true, y_pred: qloss(0.3, y_true, y_pred)
loss_50th_p = lambda y_true, y_pred: qloss(0.5, y_true, y_pred)
loss_70th_p = lambda y_true, y_pred: qloss(0.7, y_true, y_pred)
loss_90th_p = lambda y_true, y_pred: qloss(0.9, y_true, y_pred)

P_10_A = X_train.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_train.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_train.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_train.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_train.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]



rnn_train_1=X_train.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_train_2=X_train.loc[:,"WF" : "WF-143"]   
rnn_train_3=X_train.loc[:,"DF" : "DF-143"] 
rnn_train_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_train_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_train_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_train_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_train_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)


P_10_A = X_test.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_test.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_test.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_test.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_test.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]


rnn_test_1=X_test.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_test_2=X_test.loc[:,"WF":"WF-143"] 
rnn_test_3=X_test.loc[:,"DF" : "DF-143"]
rnn_test_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_test_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_test_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_test_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_test_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)

rnn_Y=Y_train.loc[:,"EURPrices":"EURPrices+23"]
rnn_test_Y=Y_test.loc[:,"EURPrices":"EURPrices+23"]

X_scaler1 = preprocessing.MinMaxScaler()
X_scaler2 = preprocessing.MinMaxScaler()
X_scaler3 = preprocessing.MinMaxScaler()
X_scaler4 = preprocessing.MinMaxScaler()
X_scaler5 = preprocessing.MinMaxScaler()
X_scaler6 = preprocessing.MinMaxScaler()
X_scaler7 = preprocessing.MinMaxScaler()
X_scaler8 = preprocessing.MinMaxScaler()

Y_scaler = preprocessing.MinMaxScaler()

rnn_scaled_train_1 = X_scaler1.fit_transform(rnn_train_1)
rnn_scaled_train_2 = X_scaler2.fit_transform(rnn_train_2)
rnn_scaled_train_3 = X_scaler3.fit_transform(rnn_train_3)
rnn_scaled_train_4 = X_scaler4.fit_transform(rnn_train_4)
rnn_scaled_train_5 = X_scaler5.fit_transform(rnn_train_5)
rnn_scaled_train_6 = X_scaler6.fit_transform(rnn_train_6)
rnn_scaled_train_7 = X_scaler7.fit_transform(rnn_train_7)
rnn_scaled_train_8 = X_scaler8.fit_transform(rnn_train_8)


Y_train_Scaled   = Y_scaler.fit_transform(rnn_Y)
Y_test_Scaled = Y_scaler.transform(rnn_test_Y)
 
X_train_Scaled = np.hstack(
    (rnn_scaled_train_1, rnn_scaled_train_2, rnn_scaled_train_3)
).reshape(rnn_train_1.shape[0], 3, 144).transpose(0, 2, 1)

X_train_Scaled_QRA = np.hstack(
    (rnn_scaled_train_4, rnn_scaled_train_5, rnn_scaled_train_6,
     rnn_scaled_train_7, rnn_scaled_train_8)
).reshape(rnn_train_4.shape[0], 5, 72).transpose(0, 2, 1)


X_test_Scaled = np.hstack(
    (X_scaler1.transform(rnn_test_1), X_scaler2.transform(rnn_test_2), X_scaler3.transform(rnn_test_3)
    )
).reshape(rnn_test_1.shape[0], 3, 144).transpose(0, 2, 1)

X_test_Scaled_QRA = np.hstack(
    (X_scaler4.transform(rnn_test_4), X_scaler5.transform(rnn_test_5), X_scaler6.transform(rnn_test_6), 
     X_scaler7.transform(rnn_test_7),X_scaler8.transform(rnn_test_8)
     )
).reshape(rnn_test_4.shape[0], 5, 72).transpose(0, 2, 1)

i_shape_QRA = (X_train_Scaled_QRA.shape[1], X_train_Scaled_QRA.shape[2])
i_shape_dnn=(X_train_Scaled.shape[1], X_train_Scaled.shape[2])

pp ={
    'dropout_rate_A': list(np.linspace(0.0,0.4, 10)),
    'dropout_rate_B': list(np.linspace(0.0,0.4, 10)),
   
    'activation_A':['relu', 'sigmoid',  'tanh'],
    'activation_B':['relu', 'sigmoid',  'tanh'],
    'activation_o_10':['relu', 'sigmoid',  'tanh'],
    'activation_o_30':['relu', 'sigmoid',  'tanh'],
    'activation_o_50':['relu', 'sigmoid',  'tanh'],
    'activation_o_70':['relu', 'sigmoid',  'tanh'],
    'activation_o_90':['relu', 'sigmoid',  'tanh'],
   
    'ffnn_neurons_A': [24, 48, 96, 192, 384, 480],
    'ffnn_neurons_B': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_10': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_30': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_50': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_70': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_90': [24, 48, 96, 192, 384, 480],
    
    'n_layer_A':[1,2,3],    
    'n_layer_B':[1,2,3],    
    'n_layer_o_10':[1,2,3],    
    'n_layer_o_30':[1,2,3],    
    'n_layer_o_50':[1,2,3],    
    'n_layer_o_70':[1,2,3],    
    'n_layer_o_90':[1,2,3],    

    
    'learning_rate': list(np.linspace(0.0001,0.02, 10)),        
    'batch_size': [4, 8, 16, 32],
    'epochs': [300]    
}


def create_model(x_train, y_train, x_val, y_val, params): 
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(params['n_layer_A']):
        input_00_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_00_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_00_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_00_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(params['n_layer_A']):
        input_10_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_10_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_10_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_10_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(params['n_layer_A']):
        input_20_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_20_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_20_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_20_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(params['n_layer_A']):
        input_30_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_30_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_30_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_30_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(params['n_layer_A']):
        input_40_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_40_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_40_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_40_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(params['n_layer_o_10']):
            merged_1 = Dense(params['n_neuro_o_10'], params['activation_o_10'])(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(params['n_layer_o_30']):
            merged_3 = Dense(params['n_neuro_o_30'], params['activation_o_30'])(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(params['n_layer_o_50']):
            merged_5 = Dense(params['n_neuro_o_50'], params['activation_o_50'])(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(params['n_layer_o_70']):
            merged_7 = Dense(params['n_neuro_o_70'], params['activation_o_70'])(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(params['n_layer_o_90']):
            merged_9 = Dense(params['n_neuro_o_90'], params['activation_o_90'])(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)


    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= params['learning_rate'])

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)


    out = model.fit(x=x_train, y=y_train, validation_data=[x_val, y_val],
                    batch_size=params['batch_size'], epochs=params['epochs'], verbose=2,
                    callbacks=[talos.utils.early_stopper(epochs=params['epochs'], mode='moderate',
                                                         min_delta=0.001, monitor='val_loss')])
    return out, model
        
h = talos.Scan(x=[X_train_Scaled_QRA, X_train_Scaled], y=[Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled],
               x_val=[X_test_Scaled_QRA, X_test_Scaled], y_val=[Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled],
               params=pp, model=create_model, experiment_name='MH_DNN_Q', round_limit=30, print_params=True, multi_input=True)

h.data.sort_values(by='val_loss', ascending=True)


def create_model():
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(1):
        input_00_A = Dense(480, 'sigmoid')(input_00_A) 
    input_00_A = Dropout(0.311111)(input_00_A)    
    for i in range(2):
        input_00_B = Dense(192, 'sigmoid')(input_00_B) 
    input_00_B = Dropout(0.177778)(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(1):
        input_10_A = Dense(480, 'sigmoid')(input_00_A) 
    input_10_A = Dropout(0.311111)(input_00_A)    
    for i in range(2):
        input_10_B = Dense(192, 'sigmoid')(input_00_B) 
    input_10_B = Dropout(0.177778)(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(1):
        input_20_A = Dense(480, 'sigmoid')(input_00_A) 
    input_20_A = Dropout(0.311111)(input_00_A)    
    for i in range(2):
        input_20_B = Dense(192, 'sigmoid')(input_00_B) 
    input_20_B = Dropout(0.177778)(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(1):
        input_30_A = Dense(480, 'sigmoid')(input_00_A) 
    input_30_A = Dropout(0.311111)(input_00_A)    
    for i in range(2):
        input_30_B = Dense(192, 'sigmoid')(input_00_B) 
    input_30_B = Dropout(0.177778)(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(1):
        input_40_A = Dense(480, 'sigmoid')(input_00_A) 
    input_40_A = Dropout(0.311111)(input_00_A)    
    for i in range(2):
        input_40_B = Dense(192, 'sigmoid')(input_00_B) 
    input_40_B = Dropout(0.177778)(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(1):
            merged_1 = Dense(96, 'tanh')(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(2):
            merged_3 = Dense(24, 'tanh')(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(3):
            merged_5 = Dense(192, 'sigmoid')(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(3):
            merged_7 = Dense(384, 'sigmoid')(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(1):
            merged_9 = Dense(384, 'sigmoid')(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)    
    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= 0.000100)

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)
    return model

mmo = KerasRegressor(build_fn=create_model, epochs=300, batch_size=4, verbose=2)
# Out:
#   0%|                                                                                                                                                                                | 0/30 [00:00<?, ?it/s]
# {'dropout_rate_A': 0.0, 'dropout_rate_B': 0.3111111111111111, 'activation_A': 'relu', 'activation_B': 'relu', 'activation_o_10': 'sigmoid', 'activation_o_30': 'relu', 'activation_o_50': 'relu', 'activation_o_70': 'tanh', 'activation_o_90': 'relu', 'ffnn_neurons_A': 192, 'ffnn_neurons_B': 96, 'n_neuro_o_10': 48, 'n_neuro_o_30': 48, 'n_neuro_o_50': 48, 'n_neuro_o_70': 384, 'n_neuro_o_90': 384, 'n_layer_A': 3, 'n_layer_B': 1, 'n_layer_o_10': 3, 'n_layer_o_30': 3, 'n_layer_o_50': 2, 'n_layer_o_70': 2, 'n_layer_o_90': 1, 'learning_rate': 0.02, 'batch_size': 32, 'epochs': 300}
# Epoch 1/300
# ...

# %%
#BM Talos Single headed network year 1 hyperparameter search w/results
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_B_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)

Y=dat.iloc[:, 0:24]
X=dat.iloc[:,24:]
X_train=X.iloc[:7296,:]
Y_train=Y.iloc[:7296,:]
X_test=X.iloc[7296:8040,:]
Y_test=Y.iloc[7296:8040,:]

def qloss(qs, y_true, y_pred):
    # Pinball loss for multiple quantiles
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

loss_10th_p = lambda y_true, y_pred: qloss(0.1, y_true, y_pred)
loss_30th_p = lambda y_true, y_pred: qloss(0.3, y_true, y_pred)
loss_50th_p = lambda y_true, y_pred: qloss(0.5, y_true, y_pred)
loss_70th_p = lambda y_true, y_pred: qloss(0.7, y_true, y_pred)
loss_90th_p = lambda y_true, y_pred: qloss(0.9, y_true, y_pred)

P_10_A = X_train.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_train.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_train.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_train.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_train.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]



rnn_train_1=X_train.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_train_2=X_train.loc[:,"WF" : "WF-143"]   
rnn_train_3=X_train.loc[:,"DF" : "DF-143"] 
rnn_train_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_train_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_train_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_train_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_train_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)


P_10_A = X_test.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_test.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_test.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_test.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_test.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]


rnn_test_1=X_test.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_test_2=X_test.loc[:,"WF":"WF-143"] 
rnn_test_3=X_test.loc[:,"DF" : "DF-143"]
rnn_test_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_test_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_test_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_test_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_test_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)

rnn_Y=Y_train.loc[:,"EURPrices":"EURPrices+23"]
rnn_test_Y=Y_test.loc[:,"EURPrices":"EURPrices+23"]

X_scaler1 = preprocessing.MinMaxScaler()
X_scaler2 = preprocessing.MinMaxScaler()
X_scaler3 = preprocessing.MinMaxScaler()
X_scaler4 = preprocessing.MinMaxScaler()
X_scaler5 = preprocessing.MinMaxScaler()
X_scaler6 = preprocessing.MinMaxScaler()
X_scaler7 = preprocessing.MinMaxScaler()
X_scaler8 = preprocessing.MinMaxScaler()

Y_scaler = preprocessing.MinMaxScaler()

rnn_scaled_train_1 = X_scaler1.fit_transform(rnn_train_1)
rnn_scaled_train_2 = X_scaler2.fit_transform(rnn_train_2)
rnn_scaled_train_3 = X_scaler3.fit_transform(rnn_train_3)
rnn_scaled_train_4 = X_scaler4.fit_transform(rnn_train_4)
rnn_scaled_train_5 = X_scaler5.fit_transform(rnn_train_5)
rnn_scaled_train_6 = X_scaler6.fit_transform(rnn_train_6)
rnn_scaled_train_7 = X_scaler7.fit_transform(rnn_train_7)
rnn_scaled_train_8 = X_scaler8.fit_transform(rnn_train_8)


Y_train_Scaled   = Y_scaler.fit_transform(rnn_Y)
Y_test_Scaled = Y_scaler.transform(rnn_test_Y)
 
X_train_Scaled = np.hstack(
    (rnn_scaled_train_1, rnn_scaled_train_2, rnn_scaled_train_3)
).reshape(rnn_train_1.shape[0], 3, 144).transpose(0, 2, 1)

X_train_Scaled_QRA = np.hstack(
    (rnn_scaled_train_4, rnn_scaled_train_5, rnn_scaled_train_6,
     rnn_scaled_train_7, rnn_scaled_train_8)
).reshape(rnn_train_4.shape[0], 5, 72).transpose(0, 2, 1)


X_test_Scaled = np.hstack(
    (X_scaler1.transform(rnn_test_1), X_scaler2.transform(rnn_test_2), X_scaler3.transform(rnn_test_3)
    )
).reshape(rnn_test_1.shape[0], 3, 144).transpose(0, 2, 1)

X_test_Scaled_QRA = np.hstack(
    (X_scaler4.transform(rnn_test_4), X_scaler5.transform(rnn_test_5), X_scaler6.transform(rnn_test_6), 
     X_scaler7.transform(rnn_test_7),X_scaler8.transform(rnn_test_8)
     )
).reshape(rnn_test_4.shape[0], 5, 72).transpose(0, 2, 1)

i_shape_QRA = (X_train_Scaled_QRA.shape[1], X_train_Scaled_QRA.shape[2])
i_shape_dnn=(X_train_Scaled.shape[1], X_train_Scaled.shape[2])


pp ={
    'dropout_rate_A': list(np.linspace(0.0,0.4, 10)),
    'dropout_rate_B': list(np.linspace(0.0,0.4, 10)),
   
    'activation_A':['relu', 'sigmoid',  'tanh'],
    'activation_B':['relu', 'sigmoid',  'tanh'],
    'activation_o_10':['relu', 'sigmoid',  'tanh'],
    'activation_o_30':['relu', 'sigmoid',  'tanh'],
    'activation_o_50':['relu', 'sigmoid',  'tanh'],
    'activation_o_70':['relu', 'sigmoid',  'tanh'],
    'activation_o_90':['relu', 'sigmoid',  'tanh'],
   
    'ffnn_neurons_A': [24, 48, 96, 192, 384, 480],
    'ffnn_neurons_B': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_10': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_30': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_50': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_70': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_90': [24, 48, 96, 192, 384, 480],
    
    'n_layer_A':[1,2,3],    
    'n_layer_B':[1,2,3],    
    'n_layer_o_10':[1,2,3],    
    'n_layer_o_30':[1,2,3],    
    'n_layer_o_50':[1,2,3],    
    'n_layer_o_70':[1,2,3],    
    'n_layer_o_90':[1,2,3],    

    
    'learning_rate': list(np.linspace(0.0001,0.02, 10)),        
    'batch_size': [4, 8, 16, 32],
    'epochs': [300]    
}


def create_model(x_train, y_train, x_val, y_val, params): 
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(params['n_layer_A']):
        input_00_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_00_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_00_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_00_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(params['n_layer_A']):
        input_10_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_10_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_10_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_10_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(params['n_layer_A']):
        input_20_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_20_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_20_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_20_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(params['n_layer_A']):
        input_30_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_30_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_30_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_30_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(params['n_layer_A']):
        input_40_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_40_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_40_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_40_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(params['n_layer_o_10']):
            merged_1 = Dense(params['n_neuro_o_10'], params['activation_o_10'])(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(params['n_layer_o_30']):
            merged_3 = Dense(params['n_neuro_o_30'], params['activation_o_30'])(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(params['n_layer_o_50']):
            merged_5 = Dense(params['n_neuro_o_50'], params['activation_o_50'])(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(params['n_layer_o_70']):
            merged_7 = Dense(params['n_neuro_o_70'], params['activation_o_70'])(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(params['n_layer_o_90']):
            merged_9 = Dense(params['n_neuro_o_90'], params['activation_o_90'])(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)


    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= params['learning_rate'])

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)


    out = model.fit(x=x_train, y=y_train, validation_data=[x_val, y_val],
                    batch_size=params['batch_size'], epochs=params['epochs'], verbose=2,
                    callbacks=[talos.utils.early_stopper(epochs=params['epochs'], mode='moderate',
                                                         min_delta=0.001, monitor='val_loss')])
    return out, model
        
h = talos.Scan(x=[X_train_Scaled_QRA, X_train_Scaled], y=[Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled],
               x_val=[X_test_Scaled_QRA, X_test_Scaled], y_val=[Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled],
               params=pp, model=create_model, experiment_name='MH_DNN_Q', round_limit=30, print_params=True, multi_input=True)

h.data.sort_values(by='val_loss', ascending=True)


def create_model():
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(3):
        input_00_A = Dense(24, 'relu')(input_00_A) 
    input_00_A = Dropout(0.177778)(input_00_A)    
    for i in range(1):
        input_00_B = Dense(384, 'sigmoid')(input_00_B) 
    input_00_B = Dropout(0.000000)(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(3):
        input_10_A = Dense(24, 'relu')(input_00_A) 
    input_10_A = Dropout(0.177778)(input_00_A)    
    for i in range(1):
        input_10_B = Dense(384, 'sigmoid')(input_00_B) 
    input_10_B = Dropout(0.000000)(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(3):
        input_20_A = Dense(24, 'relu')(input_00_A) 
    input_20_A = Dropout(0.177778)(input_00_A)    
    for i in range(1):
        input_20_B = Dense(384, 'sigmoid')(input_00_B) 
    input_20_B = Dropout(0.000000)(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(3):
        input_30_A = Dense(24, 'relu')(input_00_A) 
    input_30_A = Dropout(0.177778)(input_00_A)    
    for i in range(1):
        input_30_B = Dense(384, 'sigmoid')(input_00_B) 
    input_30_B = Dropout(0.000000)(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(3):
        input_40_A = Dense(24, 'relu')(input_00_A) 
    input_40_A = Dropout(0.177778)(input_00_A)    
    for i in range(1):
        input_40_B = Dense(384, 'sigmoid')(input_00_B) 
    input_40_B = Dropout(0.000000)(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(1):
            merged_1 = Dense(48, 'relu')(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(3):
            merged_3 = Dense(384, 'relu')(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(1):
            merged_5 = Dense(24, 'sigmoid')(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(2):
            merged_7 = Dense(192, 'tanh')(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(3):
            merged_9 = Dense(192, 'sigmoid')(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)    
    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= 0.000100)

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)
    return model

mmo = KerasRegressor(build_fn=create_model, epochs=300, batch_size=4, verbose=2)
# Out:
#   0%|                                                                                                                                                                                | 0/30 [00:00<?, ?it/s]
# {'dropout_rate_A': 0.13333333333333333, 'dropout_rate_B': 0.4, 'activation_A': 'relu', 'activation_B': 'relu', 'activation_o_10': 'relu', 'activation_o_30': 'relu', 'activation_o_50': 'sigmoid', 'activation_o_70': 'sigmoid', 'activation_o_90': 'relu', 'ffnn_neurons_A': 24, 'ffnn_neurons_B': 24, 'n_neuro_o_10': 96, 'n_neuro_o_30': 384, 'n_neuro_o_50': 384, 'n_neuro_o_70': 384, 'n_neuro_o_90': 384, 'n_layer_A': 1, 'n_layer_B': 2, 'n_layer_o_10': 2, 'n_layer_o_30': 2, 'n_layer_o_50': 3, 'n_layer_o_70': 1, 'n_layer_o_90': 3, 'learning_rate': 0.02, 'batch_size': 8, 'epochs': 300}
# Epoch 1/300
# ...

# %%
#BM Talos Single headed network year 1 hyperparameter search w/results
#full hyperparameter seaarch talos DNN/single headed(SH) model

#months 1-7 search

import numpy as np
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from math import floor
import seaborn as sns
from math import sqrt


#tensorflow &keras
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.layers import concatenate
from keras.layers import Flatten
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier

# from keras.layers.Wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
from keras.activations import *

from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)

#sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, mean_absolute_error
from sklearn.metrics import mean_squared_error as MSE
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import talos 
import tensorflow.keras.backend as K

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

date_format = "%d/%m/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat = pd.read_csv("/home/ciaran/df_SH_B_DAM_QRA.csv", index_col="DeliveryPeriod", parse_dates=True, date_parser=date_parse)


Y=dat.iloc[:, 0:24]
X=dat.iloc[:,24:]
X_train=X.iloc[:9456,:]
Y_train=Y.iloc[:9456,:]
X_test=X.iloc[9456:10200,:]
Y_test=Y.iloc[9456:10200,:]

def qloss(qs, y_true, y_pred):
    # Pinball loss for multiple quantiles
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

loss_10th_p = lambda y_true, y_pred: qloss(0.1, y_true, y_pred)
loss_30th_p = lambda y_true, y_pred: qloss(0.3, y_true, y_pred)
loss_50th_p = lambda y_true, y_pred: qloss(0.5, y_true, y_pred)
loss_70th_p = lambda y_true, y_pred: qloss(0.7, y_true, y_pred)
loss_90th_p = lambda y_true, y_pred: qloss(0.9, y_true, y_pred)

P_10_A = X_train.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_train.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_train.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_train.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_train.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_train.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_train.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]



rnn_train_1=X_train.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_train_2=X_train.loc[:,"WF" : "WF-143"]   
rnn_train_3=X_train.loc[:,"DF" : "DF-143"] 
rnn_train_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_train_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_train_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_train_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_train_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)


P_10_A = X_test.loc[:,"SH_B_EURPrices_Forecast_10+0":"SH_B_EURPrices_Forecast_10+23"]
P_10_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_10+0":"SH_B_df_EURPrices_Forecast_10+23"]
P_10_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_10+0":"SH_B_wf_EURPrices_Forecast_10+23"]

P_30_A = X_test.loc[:,"SH_B_EURPrices_Forecast_30+0":"SH_B_EURPrices_Forecast_30+23"]
P_30_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_30+0":"SH_B_df_EURPrices_Forecast_30+23"]
P_30_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_30+0":"SH_B_wf_EURPrices_Forecast_30+23"]

P_50_A = X_test.loc[:,"SH_B_EURPrices_Forecast_50+0":"SH_B_EURPrices_Forecast_50+23"]
P_50_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_50+0":"SH_B_df_EURPrices_Forecast_50+23"]
P_50_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_50+0":"SH_B_wf_EURPrices_Forecast_50+23"]

P_70_A = X_test.loc[:,"SH_B_EURPrices_Forecast_70+0":"SH_B_EURPrices_Forecast_70+23"]
P_70_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_70+0":"SH_B_df_EURPrices_Forecast_70+23"]
P_70_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_70+0":"SH_B_wf_EURPrices_Forecast_70+23"]

P_90_A = X_test.loc[:,"SH_B_EURPrices_Forecast_90+0":"SH_B_EURPrices_Forecast_90+23"]
P_90_A_df = X_test.loc[:,"SH_B_df_EURPrices_Forecast_90+0":"SH_B_df_EURPrices_Forecast_90+23"]
P_90_A_wf = X_test.loc[:,"SH_B_wf_EURPrices_Forecast_90+0":"SH_B_wf_EURPrices_Forecast_90+23"]


rnn_test_1=X_test.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_test_2=X_test.loc[:,"WF":"WF-143"] 
rnn_test_3=X_test.loc[:,"DF" : "DF-143"]
rnn_test_4= pd.concat([P_10_A, P_10_A_df, P_10_A_wf] , axis=1)
rnn_test_5= pd.concat([P_30_A, P_30_A_df, P_30_A_wf] , axis=1)
rnn_test_6= pd.concat([P_50_A, P_50_A_df, P_50_A_wf] , axis=1)
rnn_test_7= pd.concat([P_70_A, P_70_A_df, P_70_A_wf] , axis=1)
rnn_test_8= pd.concat([P_90_A, P_90_A_df, P_90_A_wf] , axis=1)

rnn_Y=Y_train.loc[:,"EURPrices":"EURPrices+23"]
rnn_test_Y=Y_test.loc[:,"EURPrices":"EURPrices+23"]

X_scaler1 = preprocessing.MinMaxScaler()
X_scaler2 = preprocessing.MinMaxScaler()
X_scaler3 = preprocessing.MinMaxScaler()
X_scaler4 = preprocessing.MinMaxScaler()
X_scaler5 = preprocessing.MinMaxScaler()
X_scaler6 = preprocessing.MinMaxScaler()
X_scaler7 = preprocessing.MinMaxScaler()
X_scaler8 = preprocessing.MinMaxScaler()

Y_scaler = preprocessing.MinMaxScaler()

rnn_scaled_train_1 = X_scaler1.fit_transform(rnn_train_1)
rnn_scaled_train_2 = X_scaler2.fit_transform(rnn_train_2)
rnn_scaled_train_3 = X_scaler3.fit_transform(rnn_train_3)
rnn_scaled_train_4 = X_scaler4.fit_transform(rnn_train_4)
rnn_scaled_train_5 = X_scaler5.fit_transform(rnn_train_5)
rnn_scaled_train_6 = X_scaler6.fit_transform(rnn_train_6)
rnn_scaled_train_7 = X_scaler7.fit_transform(rnn_train_7)
rnn_scaled_train_8 = X_scaler8.fit_transform(rnn_train_8)


Y_train_Scaled   = Y_scaler.fit_transform(rnn_Y)
Y_test_Scaled = Y_scaler.transform(rnn_test_Y)
 
X_train_Scaled = np.hstack(
    (rnn_scaled_train_1, rnn_scaled_train_2, rnn_scaled_train_3)
).reshape(rnn_train_1.shape[0], 3, 144).transpose(0, 2, 1)

X_train_Scaled_QRA = np.hstack(
    (rnn_scaled_train_4, rnn_scaled_train_5, rnn_scaled_train_6,
     rnn_scaled_train_7, rnn_scaled_train_8)
).reshape(rnn_train_4.shape[0], 5, 72).transpose(0, 2, 1)


X_test_Scaled = np.hstack(
    (X_scaler1.transform(rnn_test_1), X_scaler2.transform(rnn_test_2), X_scaler3.transform(rnn_test_3)
    )
).reshape(rnn_test_1.shape[0], 3, 144).transpose(0, 2, 1)

X_test_Scaled_QRA = np.hstack(
    (X_scaler4.transform(rnn_test_4), X_scaler5.transform(rnn_test_5), X_scaler6.transform(rnn_test_6), 
     X_scaler7.transform(rnn_test_7),X_scaler8.transform(rnn_test_8)
     )
).reshape(rnn_test_4.shape[0], 5, 72).transpose(0, 2, 1)

i_shape_QRA = (X_train_Scaled_QRA.shape[1], X_train_Scaled_QRA.shape[2])
i_shape_dnn=(X_train_Scaled.shape[1], X_train_Scaled.shape[2])

pp ={
    'dropout_rate_A': list(np.linspace(0.0,0.4, 10)),
    'dropout_rate_B': list(np.linspace(0.0,0.4, 10)),
   
    'activation_A':['relu', 'sigmoid',  'tanh'],
    'activation_B':['relu', 'sigmoid',  'tanh'],
    'activation_o_10':['relu', 'sigmoid',  'tanh'],
    'activation_o_30':['relu', 'sigmoid',  'tanh'],
    'activation_o_50':['relu', 'sigmoid',  'tanh'],
    'activation_o_70':['relu', 'sigmoid',  'tanh'],
    'activation_o_90':['relu', 'sigmoid',  'tanh'],
   
    'ffnn_neurons_A': [24, 48, 96, 192, 384, 480],
    'ffnn_neurons_B': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_10': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_30': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_50': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_70': [24, 48, 96, 192, 384, 480],
    'n_neuro_o_90': [24, 48, 96, 192, 384, 480],
    
    'n_layer_A':[1,2,3],    
    'n_layer_B':[1,2,3],    
    'n_layer_o_10':[1,2,3],    
    'n_layer_o_30':[1,2,3],    
    'n_layer_o_50':[1,2,3],    
    'n_layer_o_70':[1,2,3],    
    'n_layer_o_90':[1,2,3],    

    
    'learning_rate': list(np.linspace(0.0001,0.02, 10)),        
    'batch_size': [4, 8, 16, 32],
    'epochs': [300]    
}


def create_model(x_train, y_train, x_val, y_val, params): 
    visible1 = Input(shape=(i_shape_QRA))
    x1=visible1    
    visible2 = Input(shape=(i_shape_dnn))   
    x2= visible2
    
    input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
    input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
    input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
    for i in range(params['n_layer_A']):
        input_00_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_00_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_00_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_00_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_1 = concatenate([input_00_A, input_00_B])

       
    for i in range(params['n_layer_A']):
        input_10_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_10_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_10_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_10_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_3 = concatenate([input_10_A, input_10_B])
    
    
    for i in range(params['n_layer_A']):
        input_20_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_20_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_20_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_20_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_5 = concatenate([input_20_A, input_20_B])
    
    
    for i in range(params['n_layer_A']):
        input_30_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_30_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_30_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_30_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_7 = concatenate([input_30_A, input_30_B])
    
    
    for i in range(params['n_layer_A']):
        input_40_A = Dense(params['ffnn_neurons_A'], params['activation_A'])(input_00_A) 
    input_40_A = Dropout(params['dropout_rate_A'])(input_00_A)    
    for i in range(params['n_layer_B']):
        input_40_B = Dense(params['ffnn_neurons_B'], params['activation_B'])(input_00_B) 
    input_40_B = Dropout(params['dropout_rate_B'])(input_00_B)
    merged_9 = concatenate([input_40_A, input_40_B])
        

       
    for i in range(params['n_layer_o_10']):
            merged_1 = Dense(params['n_neuro_o_10'], params['activation_o_10'])(merged_1) 
    output_1 =  Dense(24, name='out_10')(merged_1)
    
    for i in range(params['n_layer_o_30']):
            merged_3 = Dense(params['n_neuro_o_30'], params['activation_o_30'])(merged_3) 
    output_2 =  Dense(24, name='out_20')(merged_3)

    for i in range(params['n_layer_o_50']):
            merged_5 = Dense(params['n_neuro_o_50'], params['activation_o_50'])(merged_5) 
    output_3 =  Dense(24, name='out_30')(merged_5)
    
    for i in range(params['n_layer_o_70']):
            merged_7 = Dense(params['n_neuro_o_70'], params['activation_o_70'])(merged_7) 
    output_4 =  Dense(24, name='out_40')(merged_7)
    
    for i in range(params['n_layer_o_90']):
            merged_9 = Dense(params['n_neuro_o_90'], params['activation_o_90'])(merged_9) 
    output_5 =  Dense(24, name='out_50')(merged_9)


    
    model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
    opt = Adam(learning_rate= params['learning_rate'])

    model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)


    out = model.fit(x=x_train, y=y_train, validation_data=[x_val, y_val],
                    batch_size=params['batch_size'], epochs=params['epochs'], verbose=2,
                    callbacks=[talos.utils.early_stopper(epochs=params['epochs'], mode='moderate',
                                                         min_delta=0.001, monitor='val_loss')])
    return out, model
        
h = talos.Scan(x=[X_train_Scaled_QRA, X_train_Scaled], y=[Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled,Y_train_Scaled],
               x_val=[X_test_Scaled_QRA, X_test_Scaled], y_val=[Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled, Y_test_Scaled],
               params=pp, model=create_model, experiment_name='MH_DNN_Q', round_limit=30, print_params=True, multi_input=True)

h.data.sort_values(by='val_loss', ascending=True)


# def create_model():
#     visible1 = Input(shape=(i_shape_QRA))
#     x1=visible1    
#     visible2 = Input(shape=(i_shape_dnn))   
#     x2= visible2
    
#     input_00_A = Flatten(input_shape=i_shape_QRA)(visible1)
#     input_00_B = Flatten(input_shape=i_shape_dnn)(visible2)
#     input_10_A = Flatten(input_shape=i_shape_QRA)(visible1)
#     input_10_B = Flatten(input_shape=i_shape_dnn)(visible2)
#     input_20_A = Flatten(input_shape=i_shape_QRA)(visible1)
#     input_20_B = Flatten(input_shape=i_shape_dnn)(visible2)
#     input_30_A = Flatten(input_shape=i_shape_QRA)(visible1)
#     input_30_B = Flatten(input_shape=i_shape_dnn)(visible2)
#     input_40_A = Flatten(input_shape=i_shape_QRA)(visible1)
#     input_40_B = Flatten(input_shape=i_shape_dnn)(visible2)
    
    
#     for i in range():
#         input_00_A = Dense(, '')(input_00_A) 
#     input_00_A = Dropout()(input_00_A)    
#     for i in range():
#         input_00_B = Dense(, '')(input_00_B) 
#     input_00_B = Dropout()(input_00_B)
#     merged_1 = concatenate([input_00_A, input_00_B])

       
#     for i in range():
#         input_10_A = Dense(, '')(input_00_A) 
#     input_10_A = Dropout()(input_00_A)    
#     for i in range():
#         input_10_B = Dense(, '')(input_00_B) 
#     input_10_B = Dropout()(input_00_B)
#     merged_3 = concatenate([input_10_A, input_10_B])
    
    
#     for i in range():
#         input_20_A = Dense(, '')(input_00_A) 
#     input_20_A = Dropout()(input_00_A)    
#     for i in range():
#         input_20_B = Dense(, '')(input_00_B) 
#     input_20_B = Dropout()(input_00_B)
#     merged_5 = concatenate([input_20_A, input_20_B])
    
    
#     for i in range():
#         input_30_A = Dense(, '')(input_00_A) 
#     input_30_A = Dropout()(input_00_A)    
#     for i in range():
#         input_30_B = Dense(, '')(input_00_B) 
#     input_30_B = Dropout()(input_00_B)
#     merged_7 = concatenate([input_30_A, input_30_B])
    
    
#     for i in range():
#         input_40_A = Dense(, '')(input_00_A) 
#     input_40_A = Dropout()(input_00_A)    
#     for i in range():
#         input_40_B = Dense(, '')(input_00_B) 
#     input_40_B = Dropout()(input_00_B)
#     merged_9 = concatenate([input_40_A, input_40_B])
        

       
#     for i in range():
#             merged_1 = Dense(, '')(merged_1) 
#     output_1 =  Dense(24, name='out_10')(merged_1)
    
#     for i in range():
#             merged_3 = Dense(, '')(merged_3) 
#     output_2 =  Dense(24, name='out_20')(merged_3)

#     for i in range():
#             merged_5 = Dense(, '')(merged_5) 
#     output_3 =  Dense(24, name='out_30')(merged_5)
    
#     for i in range():
#             merged_7 = Dense(, '')(merged_7) 
#     output_4 =  Dense(24, name='out_40')(merged_7)
    
#     for i in range():
#             merged_9 = Dense(, '')(merged_9) 
#     output_5 =  Dense(24, name='out_50')(merged_9)    
    
#     model = Model(inputs=[visible1, visible2], outputs=[output_1, output_2, output_3, output_4, output_5])    
#     opt = Adam(learning_rate= )

#     model.compile(loss=[loss_10th_p, loss_30th_p, loss_50th_p, loss_70th_p, loss_90th_p], optimizer=opt)
#     return model

# mmo = KerasRegressor(build_fn=create_model, epochs=300, batch_size=, verbose=2)
# Out:
# 2023-09-15 12:05:17.218953: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-15 12:05:17.247975: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 12:05:17.713288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
rnn_train_1=X_train.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_train_2=X_train.loc[:,"WF" : "WF-143"]   
rnn_train_3=X_train.loc[:,"DF" : "DF-143"]   
rnn_train_4=X_train.loc[:,"SH_A_EURPrices_Forecast_10+0" : "SH_A_EURPrices_Forecast_10+23"]    
rnn_train_5=X_train.loc[:,"SH_A_EURPrices_Forecast_30+0" : "SH_A_EURPrices_Forecast_30+23"]  
rnn_train_6=X_train.loc[:,"SH_A_EURPrices_Forecast_50+0" : "SH_A_EURPrices_Forecast_50+23"]    
rnn_train_7=X_train.loc[:,"SH_A_EURPrices_Forecast_70+0" : "SH_A_EURPrices_Forecast_70+23"]    
rnn_train_8=X_train.loc[:,"SH_A_EURPrices_Forecast_90+0" : "SH_A_EURPrices_Forecast_90+23"]    
rnn_train_9=X_train.loc[:,"SH_A_df_EURPrices_Forecast_10+0" : "SH_A_df_EURPrices_Forecast_10+23"]    
rnn_train_10=X_train.loc[:,"SH_A_df_EURPrices_Forecast_30+0" : "SH_A_df_EURPrices_Forecast_30+23"]  
rnn_train_11=X_train.loc[:,"SH_A_df_EURPrices_Forecast_50+0" : "SH_A_df_EURPrices_Forecast_50+23"]    
rnn_train_12=X_train.loc[:,"SH_A_df_EURPrices_Forecast_70+0" : "SH_A_df_EURPrices_Forecast_70+23"]    
rnn_train_13=X_train.loc[:,"SH_A_df_EURPrices_Forecast_90+0" : "SH_A_df_EURPrices_Forecast_90+23"]   
rnn_train_14=X_train.loc[:,"SH_A_wf_EURPrices_Forecast_10+0" : "SH_A_wf_EURPrices_Forecast_10+23"]    
rnn_train_15=X_train.loc[:,"SH_A_wf_EURPrices_Forecast_30+0" : "SH_A_wf_EURPrices_Forecast_30+23"]  
rnn_train_16=X_train.loc[:,"SH_A_wf_EURPrices_Forecast_50+0" : "SH_A_wf_EURPrices_Forecast_50+23"]    
rnn_train_17=X_train.loc[:,"SH_A_wf_EURPrices_Forecast_70+0" : "SH_A_wf_EURPrices_Forecast_70+23"]    
rnn_train_18=X_train.loc[:,"SH_A_wf_EURPrices_Forecast_90+0" : "SH_A_wf_EURPrices_Forecast_90+23"]   

rnn_test_1=X_test.loc[:,"EURPrices-24":"EURPrices-167"]
rnn_test_2=X_test.loc[:,"WF":"WF-143"] 
rnn_test_3=X_test.loc[:,"DF" : "DF-143"]
rnn_test_4=X_test.loc[:,"SH_A_EURPrices_Forecast_10+0" : "SH_A_EURPrices_Forecast_10+23"]    
rnn_test_5=X_test.loc[:,"SH_A_EURPrices_Forecast_30+0" : "SH_A_EURPrices_Forecast_30+23"]  
rnn_test_6=X_test.loc[:,"SH_A_EURPrices_Forecast_50+0" : "SH_A_EURPrices_Forecast_50+23"]    
rnn_test_7=X_test.loc[:,"SH_A_EURPrices_Forecast_70+0" : "SH_A_EURPrices_Forecast_70+23"]    
rnn_test_8=X_test.loc[:,"SH_A_EURPrices_Forecast_90+0" : "SH_A_EURPrices_Forecast_90+23"]    
rnn_test_9=X_test.loc[:,"SH_A_df_EURPrices_Forecast_10+0" : "SH_A_df_EURPrices_Forecast_10+23"]    
rnn_test_10=X_test.loc[:,"SH_A_df_EURPrices_Forecast_30+0" : "SH_A_df_EURPrices_Forecast_30+23"]  
rnn_test_11=X_test.loc[:,"SH_A_df_EURPrices_Forecast_50+0" : "SH_A_df_EURPrices_Forecast_50+23"]    
rnn_test_12=X_test.loc[:,"SH_A_df_EURPrices_Forecast_70+0" : "SH_A_df_EURPrices_Forecast_70+23"]    
rnn_test_13=X_test.loc[:,"SH_A_df_EURPrices_Forecast_90+0" : "SH_A_df_EURPrices_Forecast_90+23"]   
rnn_test_14=X_test.loc[:,"SH_A_wf_EURPrices_Forecast_10+0" : "SH_A_wf_EURPrices_Forecast_10+23"]    
rnn_test_15=X_test.loc[:,"SH_A_wf_EURPrices_Forecast_30+0" : "SH_A_wf_EURPrices_Forecast_30+23"]  
rnn_test_16=X_test.loc[:,"SH_A_wf_EURPrices_Forecast_50+0" : "SH_A_wf_EURPrices_Forecast_50+23"]    
rnn_test_17=X_test.loc[:,"SH_A_wf_EURPrices_Forecast_70+0" : "SH_A_wf_EURPrices_Forecast_70+23"]    
rnn_test_18=X_test.loc[:,"SH_A_wf_EURPrices_Forecast_90+0" : "SH_A_wf_EURPrices_Forecast_90+23"] 

rnn_Y=Y_train.loc[:,"EURPrices":"EURPrices+23"]
rnn_test_Y=Y_test.loc[:,"EURPrices":"EURPrices+23"]

X_scaler1 = preprocessing.MinMaxScaler()
X_scaler2 = preprocessing.MinMaxScaler()
X_scaler3 = preprocessing.MinMaxScaler()
X_scaler4 = preprocessing.MinMaxScaler()
X_scaler5 = preprocessing.MinMaxScaler()
X_scaler6 = preprocessing.MinMaxScaler()
X_scaler7 = preprocessing.MinMaxScaler()
X_scaler8 = preprocessing.MinMaxScaler()
X_scaler9 = preprocessing.MinMaxScaler()
X_scaler10 = preprocessing.MinMaxScaler()
X_scaler11 = preprocessing.MinMaxScaler()
X_scaler12 = preprocessing.MinMaxScaler()
X_scaler13 = preprocessing.MinMaxScaler()
X_scaler14 = preprocessing.MinMaxScaler()
X_scaler15 = preprocessing.MinMaxScaler()
X_scaler16 = preprocessing.MinMaxScaler()
X_scaler17 = preprocessing.MinMaxScaler()
X_scaler18 = preprocessing.MinMaxScaler()
Y_scaler = preprocessing.MinMaxScaler()

rnn_scaled_train_1 = X_scaler1.fit_transform(rnn_train_1)
rnn_scaled_train_2 = X_scaler2.fit_transform(rnn_train_2)
rnn_scaled_train_3 = X_scaler3.fit_transform(rnn_train_3)
rnn_scaled_train_4 = X_scaler4.fit_transform(rnn_train_4)
rnn_scaled_train_5 = X_scaler5.fit_transform(rnn_train_5)
rnn_scaled_train_6 = X_scaler6.fit_transform(rnn_train_6)
rnn_scaled_train_7 = X_scaler7.fit_transform(rnn_train_7)
rnn_scaled_train_8 = X_scaler8.fit_transform(rnn_train_8)
rnn_scaled_train_9 = X_scaler9.fit_transform(rnn_train_9)
rnn_scaled_train_10 = X_scaler10.fit_transform(rnn_train_10)
rnn_scaled_train_11 = X_scaler11.fit_transform(rnn_train_11)
rnn_scaled_train_12 = X_scaler12.fit_transform(rnn_train_12)
rnn_scaled_train_13 = X_scaler13.fit_transform(rnn_train_13)
rnn_scaled_train_14 = X_scaler14.fit_transform(rnn_train_14)
rnn_scaled_train_15 = X_scaler15.fit_transform(rnn_train_15)
rnn_scaled_train_16 = X_scaler16.fit_transform(rnn_train_16)
rnn_scaled_train_17 = X_scaler17.fit_transform(rnn_train_17)
rnn_scaled_train_18 = X_scaler18.fit_transform(rnn_train_18)

Y_train_Scaled   = Y_scaler.fit_transform(rnn_Y)
Y_test_scaled = Y_scaler.transform(rnn_test_Y)
 
X_train_Scaled = np.hstack(
    (rnn_scaled_train_1, rnn_scaled_train_2, rnn_scaled_train_3)
).reshape(rnn_train_1.shape[0], 3, 144).transpose(0, 2, 1)

# X_train_Scaled_QRA = np.hstack(
#     (rnn_scaled_train_4,  rnn_scaled_train_5,  rnn_scaled_train_6,  rnn_scaled_train_7,  rnn_scaled_train_8,
#      rnn_scaled_train_9,  rnn_scaled_train_10, rnn_scaled_train_11, rnn_scaled_train_12, rnn_scaled_train_13,
#      rnn_scaled_train_14, rnn_scaled_train_15, rnn_scaled_train_16, rnn_scaled_train_17, rnn_scaled_train_18)
# ).reshape(rnn_train_4.shape[0], 15, 72).transpose(0, 2, 1)
rnn_scaled_train_4.shape

# X_test_Scaled = np.hstack(
#     (X_scaler1.transform(rnn_test_1), X_scaler2.transform(rnn_test_2), X_scaler3.transform(rnn_test_3)
#     )
# ).reshape(rnn_test_1.shape[0], 3, 144).transpose(0, 2, 1)

# X_test_Scaled_QRA = np.hstack(
#     (X_scaler4.transform(rnn_test_4), X_scaler5.transform(rnn_test_5), X_scaler6.transform(rnn_test_6), X_scaler7.transform(rnn_test_7), X_scaler8.transform(rnn_test_8),
#      X_scaler9.transform(rnn_test_9), X_scaler10.transform(rnn_test_10), X_scaler11.transform(rnn_test_11), X_scaler12.transform(rnn_test_12), X_scaler13.transform(rnn_test_13),
#      X_scaler14.transform(rnn_test_14), X_scaler15.transform(rnn_test_15), X_scaler16.transform(rnn_test_16), X_scaler17.transform(rnn_test_17), X_scaler18.transform(rnn_test_18)
#      )
# ).reshape(rnn_test_4.shape[0], 15, 72).transpose(0, 2, 1) 

# i_shape_QRA = (X_train_Scaled_QRA.shape[1], X_train_Scaled_QRA.shape[2])
# i_shape_dnn=(X_train_Scaled.shape[1], X_train_Scaled.shape[2])
